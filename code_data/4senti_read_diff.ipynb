# %%
from merger_spliter import data_split
from difference_checker import difference_check

# %%
data_split(merged_info_readability_path=r'read_results\all_with_readability.csv')
# Out:
# data saved: read_results/eco_senti.csv
# data saved: read_results/genderequality_senti.csv
# data saved: read_results/health_senti.csv
# data saved: read_results/lgbtq_senti.csv
# data saved: read_results/racial_senti.csv
# data saved: read_results/war_senti.csv

# %%
difference_check(data_path=r'read_results\all_with_readability.csv',filename='all_difference.csv')
# Out:
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 28559.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 41913.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 28559.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 41913.
# ...

# %%
difference_check(data_path=r'read_results\eco_senti.csv',filename='eco_difference.csv')
# Out:
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6930.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 11496.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6930.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 11496.
# ...

# %%
difference_check(data_path=r'read_results\genderequality_senti.csv',filename='genderequality_difference.csv')
# Out:
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6511.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10811.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6511.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10811.
# ...

# %%
difference_check(data_path=r'read_results\health_senti.csv',filename='health_difference.csv')
# Out:
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 5553.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 8409.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 5553.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 8409.
# ...

# %%
difference_check(data_path=r'read_results\lgbtq_senti.csv',filename='lgbtq_difference.csv')
# Out:
# data saved: report/difference/lgbtq_difference.csv

# %%
difference_check(data_path=r'read_results\racial_senti.csv',filename='racial_difference.csv')
# Out:
# data saved: report/difference/racial_difference.csv

# %%
difference_check(data_path=r'read_results\war_senti.csv',filename='war_difference.csv')
# Out:
# data saved: report/difference/war_difference.csv
