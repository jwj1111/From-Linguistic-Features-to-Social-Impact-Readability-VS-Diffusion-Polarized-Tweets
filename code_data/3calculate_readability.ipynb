# %%
import pandas as pd
from merger_spliter import data_merge
from readability_calculator import readability_calculate

# %%
data_merge(directory_path='senti_results')
# Out:
# all_data_df saved: all_data.csv

# %%
readability_calculate(data_path='all_data.csv')
# Out:
# calculate readability...: 100%|██████████| 84717/84717 [00:29<00:00, 2823.92it/s]
# shortest 10 | longest 58
# result saved: all_with_readability.csv
