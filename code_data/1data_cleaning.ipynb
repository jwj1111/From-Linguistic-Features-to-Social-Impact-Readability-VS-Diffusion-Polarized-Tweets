# %%
from data_cleaner import data_cleaning

# %%
data_cleaning(r'raw_data\eco.csv','eco.csv')
# Out:
# e:\a1 backup\sisu\1上外课程\nlp\sentiment_readability\data_cleaner.py:11: DtypeWarning: Columns (61) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df=pd.read_csv(load_path,encoding='utf-8')
# data saved: results/eco.csv, 20500 rows in total

# %%
data_cleaning(r'raw_data\genderequality.csv','genderequality.csv')
# Out:
# e:\a1 backup\sisu\1上外课程\nlp\sentiment_readability\data_cleaner.py:11: DtypeWarning: Columns (61,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df=pd.read_csv(load_path,encoding='utf-8')
# data saved: results/genderequality.csv, 20909 rows in total

# %%
data_cleaning(r'raw_data\health.csv','health.csv')
# Out:
# data saved: results/health.csv, 16250 rows in total

# %%
data_cleaning(r'raw_data\lgbtq.csv','lgbtq.csv')
# Out:
# data saved: results/lgbtq.csv, 6932 rows in total

# %%
data_cleaning(r'raw_data\racial.csv','racial.csv')
# Out:
# data saved: results/racial.csv, 8909 rows in total

# %%
data_cleaning(r'raw_data\war.csv','war.csv')
# Out:
# e:\a1 backup\sisu\1上外课程\nlp\sentiment_readability\data_cleaner.py:11: DtypeWarning: Columns (3,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df=pd.read_csv(load_path,encoding='utf-8')
# data saved: results/war.csv, 11217 rows in total
