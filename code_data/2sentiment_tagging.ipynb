# %%
from sentiment_tagger import senti_tagging

# %%
senti_tagging(r'results\eco.csv',r'eco_senti.csv',modelname='tabularisai/robust-sentiment-analysis')
# Out:
# sentiment tagging...:   0%|          | 0/20500 [00:00<?, ?it/s]d:\anaconda3\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:402: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# sentiment tagging...: 100%|██████████| 20500/20500 [01:05<00:00, 315.15it/s]
# data saved: senti_results/eco_senti.csv, polarized rows 7532/20500

# %%
senti_tagging(r'results\genderequality.csv',r'genderequality_senti.csv',modelname='tabularisai/robust-sentiment-analysis')
# Out:
# sentiment tagging...: 100%|██████████| 20909/20909 [01:04<00:00, 324.93it/s]
# data saved: senti_results/genderequality_senti.csv, polarized rows 7885/20909

# %%
senti_tagging(r'results\health.csv',r'health_senti.csv',modelname='tabularisai/robust-sentiment-analysis')
# Out:
# sentiment tagging...: 100%|██████████| 16250/16250 [00:59<00:00, 274.03it/s]
# data saved: senti_results/health_senti.csv, polarized rows 6312/16250

# %%
senti_tagging(r'results\lgbtq.csv',r'lgbtq_senti.csv',modelname='tabularisai/robust-sentiment-analysis')
# Out:
# sentiment tagging...: 100%|██████████| 6932/6932 [00:26<00:00, 262.38it/s]
# data saved: senti_results/lgbtq_senti.csv, polarized rows 3164/6932

# %%
senti_tagging(r'results\racial.csv',r'racial_senti.csv',modelname='tabularisai/robust-sentiment-analysis')
# Out:
# sentiment tagging...: 100%|██████████| 8909/8909 [00:33<00:00, 269.29it/s]
# data saved: senti_results/racial_senti.csv, polarized rows 3762/8909

# %%
senti_tagging(r'results\war.csv',r'war_senti.csv',modelname='tabularisai/robust-sentiment-analysis')
# Out:
# sentiment tagging...: 100%|██████████| 11217/11217 [00:44<00:00, 254.76it/s]
# data saved: senti_results/war_senti.csv, polarized rows 5304/11217
