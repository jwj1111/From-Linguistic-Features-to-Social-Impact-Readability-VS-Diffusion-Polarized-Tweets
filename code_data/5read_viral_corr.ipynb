# %%
from corr_checker import check_corr

# %%
check_corr(r'read_results\all_with_readability.csv','all_corr.csv')
# Out:
# data saved: report/correlation/all_corr.csv
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 28559.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 28559.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 28559.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 28559.
# ...

# %%
check_corr(r'read_results\eco_senti.csv','eco_corr.csv')
# Out:
# data saved: report/correlation/eco_corr.csv
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6930.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6930.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6930.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6930.
# ...

# %%
check_corr(r'read_results\genderequality_senti.csv','genderequality_corr.csv')
# Out:
# data saved: report/correlation/genderequality_corr.csv
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6511.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6511.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6511.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6511.
# ...

# %%
check_corr(r'read_results\health_senti.csv','health_corr.csv')
# Out:
# data saved: report/correlation/health_corr.csv
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 5553.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 5553.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 5553.
#   stats = numdata.apply(lambda x: func(x.dropna()), result_type="expand", axis=0).T
# d:\anaconda3\Lib\site-packages\pingouin\distribution.py:230: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 5553.
# ...

# %%
check_corr(r'read_results\lgbtq_senti.csv','lgbtq_corr.csv')
# Out:
# data saved: report/correlation/lgbtq_corr.csv

# %%
check_corr(r'read_results\racial_senti.csv','racial_corr.csv')
# Out:
# data saved: report/correlation/racial_corr.csv

# %%
check_corr(r'read_results\war_senti.csv','war_corr.csv')
# Out:
# data saved: report/correlation/war_corr.csv
